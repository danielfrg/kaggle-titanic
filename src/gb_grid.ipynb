# %%
# %load_ext autoreload
# %autoreload 2
import copper
import pandas as pd
import numpy as np
copper.project.path = '../'
plt.rcParams['figure.figsize'] = 10, 7.55

# %%
from sklearn.ensemble import GradientBoostingClassifier

# %%
train = copper.load('train')

# %%
clf = GradientBoostingClassifier()

# %%
values = [10, 100, 200]

# %%
train_scores, test_scores = copper.utils.ml.grid(train, clf, 'n_estimators', values, verbose=True)
# Out:
# n_estimators= 10
# n_estimators= 100
# n_estimators= 200

# %%
copper.plot.grid(values, train_scores, test_scores)

# %%
values = [200, 500, 1000]

# %%
train_scores, test_scores = copper.utils.ml.grid(train, clf, 'n_estimators', values, verbose=True)
# Out:
# n_estimators= 200
# n_estimators= 500
# n_estimators= 1000

# %%
copper.plot.grid(values, train_scores, test_scores)

# %% [markdown]
# ## max_depth

# %%
clf = GradientBoostingClassifier(n_estimators=50)

# %%
values = [3, 6, 9]

# %%
train_scores, test_scores = copper.utils.ml.grid(train, clf, 'max_depth', values, verbose=True)
# Out:
# max_depth= 3
# max_depth= 6
# max_depth= 9

# %%
copper.plot.grid(values, train_scores, test_scores)
