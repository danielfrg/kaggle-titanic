# %%
# %load_ext autoreload
# %autoreload 2
import copper
import pandas as pd
import numpy as np
copper.project.path = '../'
plt.rcParams['figure.figsize'] = 10, 7.55

# %%
train = copper.load('train')

# %%
test = copper.load('test')

# %%
train.skew(role=train.INPUT)
# Out:
# fare      4.787317
# sibsp     3.695352
# parch     2.749117
# age       0.434488
# pclass   -0.630548

# %%
train.histogram('fare', bins=50, legend=False)

# %%
train['fare'].plot(kind='kde')

# %%
log = train['fare'].apply(np.log1p)

# %%
log.plot(kind='kde')

# %%
train['fare'] = log

# %%
train.histogram('fare', bins=50, legend=False)

# %%
train.save('train_log.ds')

# %% [markdown]
# ## TEST

# %%
test['age'] = test['age'].apply(np.log1p)

# %%
test.histogram('age', bins=50, legend=False)

# %%
test.save('test_log.ds')
