# %%
# %load_ext autoreload
# %autoreload 2
import copper
import pandas as pd
import numpy as np
copper.project.path = '../'
plt.rcParams['figure.figsize'] = 10, 7.55

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf = RandomForestClassifier(n_estimators=100, max_depth=6)

# %%
train = copper.load('train')

# %%
mc = copper.ModelComparison()

# %%
mc.sample(train, 0.7)

# %%
copper.transform.inputs2ml(train).columns
# Out:
# Index([pclass, age, sibsp, parch, fare, sex#female, sex#male, embarked#C, embarked#Q, embarked#S], dtype=object)

# %%
div_wrapper = copper.SplitWrapper(rf, train, 'embarked')

# %%
div_wrapper.fit(mc.X_train, mc.y_train)

# %%
div_wrapper.predict_proba(mc.X_test)
# Out:
# [(0, 2), (2, 4), (4, 6)]
# array([[ 0.95499664,  0.04500336],
#        [ 0.65859927,  0.34140073],
#        [ 0.87740209,  0.12259791],
#        [ 0.90960273,  0.09039727],
#        [ 0.87675396,  0.12324604],
#        [ 0.71296319,  0.28703681],
#        [ 0.87675396,  0.12324604],
#        [ 0.87675396,  0.12324604],
#        [ 0.83210789,  0.16789211],
#        [ 0.65915632,  0.34084368],
#        [ 0.90960273,  0.09039727],
#        [ 0.93722254,  0.06277746],
#        [ 0.86183642,  0.13816358],
#        [ 0.73612152,  0.26387848],
#        [ 0.84244549,  0.15755451],
#        [ 0.11705841,  0.88294159],
#        [ 0.13478545,  0.86521455],
#        [ 0.63665517,  0.36334483],
#        [ 0.02      ,  0.98      ],
#        [ 0.52691744,  0.47308256],
#        [ 0.59081668,  0.40918332],
#        [ 0.60963113,  0.39036887],
#        [ 0.78070239,  0.21929761],
#        [ 0.04124604,  0.95875396],
#        [ 0.24747348,  0.75252652],
#        [ 0.83149999,  0.16850001],
# ...
