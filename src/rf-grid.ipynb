# %%
# %load_ext autoreload
# %autoreload 2
import copper
import pandas as pd
import numpy as np
copper.project.path = '../'
plt.rcParams['figure.figsize'] = 10, 7.55

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
train = copper.load('train')

# %%
train.role['sibsp'] = train.REJECT
train.role['parch'] = train.REJECT
train.role['parch'] = train.REJECT

# %%
clf = RandomForestClassifier()

# %%
values = [10, 100, 200]

# %%
train_scores, test_scores = copper.utils.ml.grid(train, clf, 'n_estimators', values)

# %%
copper.plot.grid(values, train_scores, test_scores)

# %% [markdown]
# ## max_depth

# %%
clf = RandomForestClassifier()

# %%
values = [3, 6, 9, 12, 15, 18]

# %%
train_scores, test_scores = copper.utils.ml.grid(train, clf, 'max_depth', values)

# %%
copper.plot.grid(values, train_scores, test_scores)
