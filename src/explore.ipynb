# %%
# %load_ext autoreload
# %autoreload 2
import copper
import pandas as pd
import numpy as np
copper.project.path = '../'
plt.rcParams['figure.figsize'] = 10, 7.55

# %%
train = copper.load('train')

# %%
train.scatter_pca()

# %% [markdown]
# ## Outliers

# %%
train.outlier_count()
# Out:
# parch     213
# fare      116
# age        66
# sibsp      46
# pclass      0

# %% [markdown]
# ## Distribution

# %%
len(train['survived'][train['survived'] == 0]), len(train['survived'][train['survived'] == 1])
# Out:
# (549, 342)

# %%
train.frame.skew()
# Out:
# survived    0.478523
# pclass     -0.630548
# age         0.434488
# sibsp       3.695352
# parch       2.749117
# fare        4.787317
